# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import random
from sklearn.neighbors import NearestNeighbors
import numpy as np
class Smote:
    def __init__(self,samples,N=10,k=5):
        self.n_samples,self.n_attrs=samples.shape
        self.N=N
        self.k=k
        self.samples=samples
        self.newindex=0

    def over_sampling(self):
        N=int(self.N)
        self.synthetic = np.zeros((self.n_samples * N, self.n_attrs))
        neighbors=NearestNeighbors(n_neighbors=self.k).fit(self.samples)  
        for i in range(len(self.samples)):
#             print('samples',self.samples[i])
            nnarray=neighbors.kneighbors(self.samples[i].reshape((1,-1)),return_distance=False)[0]  #Finds the K-neighbors of a point.
#             print ('nna',nnarray)
            self._populate(N,i,nnarray)
        return self.synthetic


    # for each minority class sample i ,choose N of the k nearest neighbors and generate N synthetic samples.
    def _populate(self,N,i,nnarray):
        for j in range(N):
            nn=random.randint(0,self.k-1)
            dif=self.samples[nnarray[nn]]-self.samples[i]
            gap=random.random()
            self.synthetic[self.newindex]=self.samples[i]+gap*dif
            self.newindex+=1
#             print(self.synthetic)
            
# a=np.array([[1,2,3],[4,5,6],[2,3,1],[2,1,2],[2,3,4],[2,3,4]])
# s=Smote(a,N=10)
# n= s.over_sampling()
# print(np.shape(n))

# %%
def save_balanced_data( train_i,train_t,test_i,test_t,train_name="balanced_train",test_name="test"):
    
    fp = open('./Balanced-data/'+train_name+'.txt','w+')
    for i in range(len(train_i)):
        d_str = str(train_t[i]) + '\t' +str(train_i[i,:].tolist())[1:-1].replace(',','') +'\n'
        fp.write(d_str)
    fp.close()
    
    fp = open('./Balanced-data/'+test_name+'.txt', 'w+')
    for i in range(len(test_i)):
        d_str = str(test_t[i]) + '\t' + str(test_i[i, :].tolist())[1:-1].replace(',','') + '\n'
        fp.write(d_str)
    fp.close()

    pass


def balance_data(aep_i,aep_t, non_aep_i,non_aep_t,pattern_N= 400,method ='downsampling', test_aep_ratio= 0.3,test_nonaep_ratio= 0.3):
    """

    :param aep_i:
    :param aep_t:
    :param non_aep_i:
    :param non_aep_t:
    :param pattern_N: the number of training input of each pattern
    :param method:
    :param test_aep_ratio:
    :param test_nonaep_ratio:
    :return:
    """

    print("Original data size:")
    print("aep:",len(aep_i),'non_aep:',len(non_aep_i))
    # split test set and train set
    test_aep_sample = int(test_aep_ratio*len(aep_i))
    aep_test_i = aep_i[0:test_aep_sample,:]
    aep_test_t = aep_t[0:test_aep_sample]
    
    test_nonaep_sample = int(test_nonaep_ratio*len(non_aep_i))
    non_aep_test_i = non_aep_i[0:test_nonaep_sample,:]
    non_aep_test_t = non_aep_t[0:test_nonaep_sample]

    # test set
    test_i = np.concatenate((aep_test_i,non_aep_test_i),axis=0)
    test_t = []
    test_t.extend(aep_test_t)
    test_t.extend( non_aep_test_t)

    # train set
    aep_i =aep_i[test_aep_sample:,:]
    aep_t = np.array(aep_t[test_aep_sample:])
    non_aep_i = non_aep_i[test_nonaep_sample:, :]
    non_aep_t = non_aep_t[test_nonaep_sample:]

 
    # balance training set here
    if method == 'oversampling':
        print("Using oversampling...")
        sample_range = len(aep_i)
        indices = np.random.randint(sample_range, size=len(non_aep_i))
        new_aep_i = aep_i[indices,:]
        new_aep_t = aep_t[indices]
        
        train_i = np.concatenate((new_aep_i, non_aep_i),axis=0)
        train_t =[]
        train_t.extend(new_aep_t)
        train_t.extend(non_aep_t)


    elif method == 'downsampling':
        print("Using downsampling...")
        sample_range = len(non_aep_i)
        indices = np.random.randint(sample_range, size=len(aep_i))
        new_nonaep_i = non_aep_i[indices,:]
        new_nonaep_t = non_aep_t[indices]
        
        train_i = np.concatenate((aep_i,new_nonaep_i),axis=0)
        train_t =[]
        train_t.extend(aep_t)
        train_t.extend(new_nonaep_t)
        pass
    elif method == 'SMOTE':
        print("Using SMOTE...")
        #generate new aep data
        s= Smote(aep_i,N=10*len(aep_i))
        new_aep_i = s.over_sampling()
        indices = np.random.randint(len(new_aep_i), size=pattern_N)
        new_aep_i = new_aep_i[indices,:]
        new_aep_t = [1.0]*len(new_aep_i)
        
        #downsample non aep data and make aep and non_aep data have same size 
        indices = np.random.randint(len(non_aep_i), size=len(new_aep_i))
        new_nonaep_i = non_aep_i[indices,:]
        new_nonaep_t = non_aep_t[indices]
        #first half of data is aep, second half of data is non_aep
        train_i = np.concatenate((new_aep_i,new_nonaep_i),axis=0)
        train_t =[]
        train_t.extend(new_aep_t)
        train_t.extend(new_nonaep_t)
        
    else:
        print("Using downsampling+ oversampling...")
        #Default downsample non_aep data and oversample aep data randomly
        #downsample non_aep data
        sample_size = pattern_N
        indices = np.random.randint(len(non_aep_i), size=sample_size)
        new_nonaep_i = non_aep_i[indices,:]
        new_nonaep_t = non_aep_t[indices]
        #oversample aep data
        indices = np.random.randint(len(aep_i), size=sample_size)
        new_aep_i = aep_i[indices,:]
        new_aep_t = aep_t[indices]
        
        train_i = np.concatenate((new_aep_i,new_nonaep_i),axis=0)
        train_t =[]
        train_t.extend(new_aep_t)
        train_t.extend(new_nonaep_t)
        pass


    return train_i,train_t,test_i,test_t



def load_balanced_data(train_name="balanced_train",test_name="test"):
   
    train_i = []
    train_t = []
    test_i = []
    test_t = []
    fp = open('./Balanced-data/'+train_name+'.txt','r')
    lines= fp.readlines()
    for line in lines:
        line = line.split('\n')[0]
        target, inputs =line.split('\t')[0],line.split('\t')[1]
        data = [float(s) for s in inputs.split(' ') if s != '']
        train_t.append(float(target))
        train_i.append(data)
    fp.close()
    
    fp = open('./Balanced-data/'+test_name+'.txt','r')
    lines= fp.readlines()
    for line in lines:
        line = line.split('\n')[0]
        target, inputs =line.split('\t')[0],line.split('\t')[1]
        data = [float(s) for s in inputs.split(' ') if s != '']
        test_t.append(float(target))
        test_i.append(data)
    fp.close()
    
    train_i, train_t, test_i, test_t = np.array(train_i),np.array(train_t),np.array(test_i),np.array(test_t)
    
    return train_i, train_t, test_i, test_t



def create_balanced_data(method="SMOTE"):
    fp = open('db4_Diff1f_100_128w_AEP2_gp2_ver1-1_ece856.txt', 'r+')
    lines = fp.readlines()
    aep_i = []
    aep_t = []
    non_aep_i = []
    non_aep_t = []

    for line in lines:
        line = line.split('\n')[0]
        data = [float(s) for s in line.split(' ') if s != '']
        aep_i.append(data)
        aep_t.append(1)
    fp.close()

    aep_i = np.array(aep_i)
    aep_t = np.array(aep_t)

    fp = open('db4_Diff1f_100_128w_nonAEP2_gp2_ver1-1_ece856.txt', 'r+')
    lines = fp.readlines()
    for line in lines:
        line = line.split('\n')[0]
        data = [float(s) for s in line.split(' ') if s != '']
        non_aep_i.append(data)
        non_aep_t.append(0)
    fp.close()
    non_aep_i = np.array(non_aep_i)
    non_aep_t = np.array(non_aep_t)

    
    
    train_i, train_t, test_i, test_t= balance_data(aep_i,aep_t,non_aep_i,non_aep_t,method=method)
    
    train_i, train_t, test_i, test_t = np.array(train_i),np.array(train_t),np.array(test_i),np.array(test_t)
    return train_i, train_t, test_i, test_t

# %%
class MLFF():
    def __init__(self,input_shape = 27, bias=False):
#         np.random.seed(1)
        self.weights = {}
        self.bias_enabled = bias
        self.weight_correction = {}
        self.delta ={}
        self.input_shape = input_shape
        self.num_layer = 1 # initialize input layer
        self.func_pair = {'logistic':(self.logistic,self.d_logistic),'relu':(self.relu,self.d_relu),'tanh':(self.tanh,self.d_tanh)}
        self.activate = {}
        self.derivative = {}
        
    def add_layer(self,shape, activation=None,initializer='random'):
        if initializer =='zero':
            # zero initializer
            self.weights[self.num_layer] = np.vstack((np.zeros(shape[1]), np.zeros((shape))))
        else:
            #random initializer
            # The first row is bias 
            self.weights[self.num_layer] = np.vstack((10*np.random.random(shape[1])-5, 10*np.random.random(shape)-5))
        self.weight_correction[self.num_layer]= np.zeros((shape[0]+1, shape[1]))
        
        self.num_layer += 1
        
        # the address to activation function
        if activation is not None and activation is not '':
            self.activate[self.num_layer] = self.func_pair[activation][0]
            self.derivative[self.num_layer] = self.func_pair[activation][1]
        else:
            self.activate[self.num_layer] = self.logistic
            self.derivative[self.num_layer] = self.d_logistic
            
        
    def logistic(self, net):
        k = 0.01
        return 1/(1+ np.exp(-k*net))
    
    def d_logistic(self,net,out):
        """
        out: numpy array
        """
        k = 0.01
        return k*out*(1.0- out)

    
    def tanh(self,net):
        return np.tanh(net)
    
    def d_tanh(self,net,o):
        return 1.0-np.square(o)
    
    def relu(self,net):
        k =1.0
        k1= 0.1
        ma = k*np.maximum(net, np.zeros(np.shape(net)))
        mi = k1*np.minimum(net, np.zeros(np.shape(net)))
        return ma+mi
    
    def d_relu(self, net,o):
        k = 1.0
        k1 = 0.1
        z = np.zeros(np.shape(net))
        m = np.maximum(z,net)
        deriv = np.where(m>0.0,k,m)
        deriv = np.where(deriv==0.0,k1,deriv)
        return deriv
    
    
    def feedforward(self,inputs,bias= False):
        """
        input: 1-D array
        """
        out = {}
        out[1] = inputs
        for i in range(self.num_layer-1):
            layer = i+1
            net = np.dot(out[layer], self.weights[layer][1:,:])
            if bias:
                net += self.weights[layer][0,:]
            out[layer+1]= self.activate[layer+1](net)
            
        return out, out[self.num_layer]
    
        
    def backforward(self,out, target,bias = False):
        """
        Apply General delta rule to backforward
        out: the dictionary storing all outputs in different layers
        """
        pred = out[self.num_layer]
        dE_o = -(target- pred)
        prev_net = np.dot(out[self.num_layer-1], self.weights[self.num_layer-1][1:,:])
        if bias:
            prev_net += self.weights[self.num_layer-1][0,:]
        
        
        
        self.delta[self.num_layer] = -np.multiply(dE_o, self.derivative[self.num_layer](prev_net,pred) )
        # calculate delta of each layer
        # calculate delta from layer-2 to the last second layer,since the input layer doesn't have delta
        # delta  of the output layer is determined by output
        for layer in reversed(range(2, self.num_layer)):
            last_delta = self.delta[layer+1] 
            
            dE_o =np.dot(self.weights[layer][1:,:], last_delta)
            prev_net = np.dot(out[layer-1], self.weights[layer-1][1:,:])
            if bias:
                prev_net += self.weights[layer-1][0,:]
                
            d_f =self.derivative[layer](prev_net,out[layer])
            self.delta[layer] = -np.multiply(dE_o, d_f)
            
#             print('last-delta:',np.shape(last_delta),last_delta, "weights-",layer,': ',self.weights[layer][1:,:])
#             print('layer:',layer)
#             print('prev_net:',prev_net)
#             print('out:',out[layer])
#             print('dE_o-',layer,": ",dE_o,'d_f:',d_f,'delta:',np.shape(self.delta[layer]),self.delta[layer])
        
        #calculate weight correction
        for layer in range(1, self.num_layer):
            self.weight_correction[layer][1:,:] += np.multiply(self.delta[layer+1],np.reshape(out[layer], (len(out[layer]), 1)))
            #update bias if enabled
            if bias:
                self.weight_correction[layer][0,:] += self.delta[layer+1]
            
        return None
    
    
    def predict(self, inputs,bias=False):
        _, preds = self.feedforward(inputs,bias)
        preds = np.array([1 if p>=0.5 else 0 for p in preds])
        return preds
    
    def gradient_descent(self,alpha,beta,momentum= None):
        
        new_momentum= self.weight_correction.copy()
        for layer in range(1, self.num_layer):
            if momentum is not None:
                self.weight_correction[layer] = alpha*self.weight_correction[layer] + beta* momentum[layer]
            else:
                self.weight_correction[layer] = alpha*self.weight_correction[layer]
            self.weights[layer] += self.weight_correction[layer]
            #update momentum
            new_momentum[layer] = self.weight_correction[layer]
            #reset weight correction after updating weights
            self.weight_correction[layer]= np.zeros(np.shape(self.weight_correction[layer]))

        return new_momentum
        
    
    def train(self,inputs,targets,adaptive_rate=True,alpha0=0.9, beta0=0.5,
              bias =False,momentum_enabled = False,max_iteration = 1000,interval =100):
        pre_err= 0.0
        sens = 0.0
        spec =0.0
        e_th = 70.0
        threshold = 1e-3
        momentum  = None
        Etss = []
        sensitivity = []
        specificity = []
        
        for epoch in range(max_iteration):
            err = 0.0
            #need to decrease learning rate alpha, otherwise, it would not decrease error, error doesn't converge
            if adaptive_rate:
                alpha = alpha0/float(0.01*epoch+1)
                
            else:
                alpha = alpha0
            
            beta = beta0

            for i in range(len(inputs)):
                outs, pred= self.feedforward(inputs[i,:],bias)
                
                err  += 0.5*pow(targets[i]-pred[0], 2)
                self.backforward(outs,targets[i],bias)
            #trained by epoch
            m = self.gradient_descent(alpha, beta,momentum)
            #update momentum if enabled
            if momentum:
                momentum = m
            #save data every 10 epochs
            if epoch % 100 == 0:
                preds = self.predict(inputs,bias)
                eap_cnts = float(np.sum(targets))
                TP = np.sum(preds[np.where(targets == 1)])
                sens = TP/eap_cnts
                
                noneap_cnts =float(len(targets) - float(np.sum(targets))) 
                TN = len(preds[np.where(targets == 0)])- np.sum(preds[np.where(targets == 0)])
                spec = TN/noneap_cnts
                sensitivity.append(sens)
                
                specificity.append(spec)
                Etss.append(err)
                #print data after every interval epochs pass
                if  epoch%interval == 0:  
                    print("Epoch:", epoch,"Error:",err,"Sensitivity:",sens,"specificity:",spec)
            
            
            if epoch>1 and ( err<=e_th ):
                break
            
            else:
                pre_err = err
            
        return Etss, specificity, sensitivity

# %%
## generate and save balanced data here
train_i, train_t, test_i, test_t = create_balanced_data(method="")
save_balanced_data(train_i, train_t, test_i, test_t)
print("shape:",np.shape(train_i),np.shape(train_t),np.shape(test_i))
# Out:
# Original data size:
# aep: 83 non_aep: 2482
# Using downsampling+ oversampling...
# shape: (800, 27) (800,) (768, 27)

# %%
# load balanced data and shuffle them
train_i, train_t, test_i, test_t = load_balanced_data()
print("shape:",np.shape(train_i),np.shape(train_t),np.shape(test_i),np.shape(test_t))
# print((train_t[0:500]),(train_t[500:]))

from sklearn.utils import shuffle
train_i, train_t = shuffle(train_i, train_t)
# Out:
# shape: (800, 27) (800,) (768, 27) (768,)

# %%
#normalize data
len_train = len(train_i)
len_test = len(test_i)
data = np.concatenate([train_i,test_i])
#normalize data to range [-1,1]
new_max =1.0
new_min = -1.0
norm_data = ((data- np.min(data,axis=0))/(np.max(data,axis=0) - np.min(data,axis=0)))*(new_max-new_min)+new_min
norm_train_i = norm_data[0:len_train,:]
test_i = norm_data[len_train:,:]
np.shape(norm_data), np.shape(data), np.shape(norm_train_i), np.shape(test_i)
# Out:
# ((1568, 27), (1568, 27), (800, 27), (768, 27))

# %%
# save weights
def save_weights(w,i):
    import json
    fp = open("weights/model_case_"+str(i)+".txt","w+")
    fp.write(json.dumps(w))
    fp.close()

def load_weights(model):
    import json
    i =1 if model =='model_1' else 2
    fp = open("weights/model_case_"+str(i)+".txt","r")
    line= fp.read()
    w= json.loads(line)
    return {1:np.array(w['1']),2:np.array(w['2'])}

def save_curves(case,name,epoch,err, sens,specif):
    import json
    fp = open("Case-"+str(case)+"-data"+"/log_"+name+".txt","w+")
    for i in range(len(epoch)):
        fp.write(str(epoch[i])+" "+str(err[i])+" "+str(sens[i])+" "+str(specif[i]))
           
    fp.close()

# %%
#initialize weights of case 1 randomly
# if using relu, max iteration =1000,  learning rate <=0.001
d = 27
model_1 = MLFF(input_shape  = d)
model_1.add_layer((d,2*d+1),activation='relu')
model_1.add_layer((2*d+1,1),initializer='')
#backup weights of case 1
model_1_weights = model_1.weights.copy()

# %%
#save weights here
# d1= {1:model_1_weights[1].tolist(),2:model_1_weights[2].tolist()}
# save_weights( d1,1)

w1= load_weights("model_1")
list(set(d1)-set(w1))
# Out:
# []

# %%
#case 1: determine learning rate

model_1.weights=load_weights("model_1")
Etss_1b, specif_1b, sens_1b = model_1.train(norm_train_i,train_t,adaptive_rate = False,alpha0= 0.001,
                                   bias=False,momentum_enabled=False ,max_iteration = 3000,interval=100)
epochs = [i*500 for i in range(len(Etss_1b))]
save_curves(1,"rate_0.001",epochs,Etss_1b, specif_1b, sens_1b )
# Out:
# Epoch: 0 Error: 127.76428086786105 Sensitivity: 0.0 specificity: 0.9975
# Epoch: 100 Error: 125.9061504899955 Sensitivity: 0.0 specificity: 0.9975
# Epoch: 200 Error: 121.54520113677061 Sensitivity: 0.0 specificity: 0.9975
# Epoch: 300 Error: 115.83959625344403 Sensitivity: 0.0 specificity: 0.99
# Epoch: 400 Error: 109.86704220410365 Sensitivity: 0.0 specificity: 0.975
# Epoch: 500 Error: 104.83848396725531 Sensitivity: 0.0275 specificity: 0.925
# Epoch: 600 Error: 102.13263019711036 Sensitivity: 0.27 specificity: 0.795
# Epoch: 700 Error: 101.54899407364947 Sensitivity: 0.4175 specificity: 0.6925
# Epoch: 800 Error: 101.54170085131157 Sensitivity: 0.5 specificity: 0.64
# Epoch: 900 Error: 101.70760922222925 Sensitivity: 0.5 specificity: 0.5825
# Epoch: 1000 Error: 101.88624868445689 Sensitivity: 0.5 specificity: 0.5625
# Epoch: 1100 Error: 102.01511643693169 Sensitivity: 0.5 specificity: 0.555
# Epoch: 1200 Error: 102.13324368550022 Sensitivity: 0.5 specificity: 0.5525
# Epoch: 1300 Error: 102.18686877121924 Sensitivity: 0.5 specificity: 0.5525
# Epoch: 1400 Error: 102.23672061231316 Sensitivity: 0.5 specificity: 0.5525
# Epoch: 1500 Error: 102.24055598254851 Sensitivity: 0.5 specificity: 0.555
# Epoch: 1600 Error: 102.23379061447343 Sensitivity: 0.5 specificity: 0.5575
# Epoch: 1700 Error: 102.21495263252469 Sensitivity: 0.53 specificity: 0.545
# Epoch: 1800 Error: 102.19775216966433 Sensitivity: 0.53 specificity: 0.55
# Epoch: 1900 Error: 102.18238055379197 Sensitivity: 0.53 specificity: 0.5525
# Epoch: 2000 Error: 102.1901909996536 Sensitivity: 0.5475 specificity: 0.55
# Epoch: 2100 Error: 102.16275960591078 Sensitivity: 0.5475 specificity: 0.55
# Epoch: 2200 Error: 102.12361664435707 Sensitivity: 0.5475 specificity: 0.555
# Epoch: 2300 Error: 102.07103710559664 Sensitivity: 0.5525 specificity: 0.56
# Epoch: 2400 Error: 102.04160745763414 Sensitivity: 0.5525 specificity: 0.555
# Epoch: 2500 Error: 102.02855693762632 Sensitivity: 0.5525 specificity: 0.55
# Epoch: 2600 Error: 101.99486893810071 Sensitivity: 0.555 specificity: 0.5525
# Epoch: 2700 Error: 101.99104420631812 Sensitivity: 0.555 specificity: 0.5525
# Epoch: 2800 Error: 101.97159369953185 Sensitivity: 0.555 specificity: 0.5625
# Epoch: 2900 Error: 101.96801223823117 Sensitivity: 0.555 specificity: 0.5625

# %%
preds = model_1.predict(test_i,bias=False)
acc = float(list(np.logical_xor(test_t,preds)).count(False))/len(test_t)
print("Model 1 acc:",acc)
# print(Etss_1b, specif_1b, sens_1b )
# Out:
# Model 1 acc: 0.5598958333333334

# %%
#case 1: determine learning rate
w1= load_weights("model_1")
model_1.weights=w1.copy()
Etss_1a, specif_1a, sens_1a = model_1.train(norm_train_i,train_t,adaptive_rate = False,alpha0= 0.003,
                                   bias=False,momentum_enabled=False ,max_iteration = 4000)
# Out:
# Epoch: 0 Error: 127.76428086786098 Sensitivity: 0.0 specificity: 0.9975
# Epoch: 100 Error: 115.8302863874128 Sensitivity: 0.0 specificity: 0.99
# Epoch: 200 Error: 102.11403609722234 Sensitivity: 0.27 specificity: 0.79
# Epoch: 300 Error: 101.70947295805891 Sensitivity: 0.5 specificity: 0.58
# Epoch: 400 Error: 102.13174439954517 Sensitivity: 0.5 specificity: 0.5525
# Epoch: 500 Error: 102.24779071553947 Sensitivity: 0.5 specificity: 0.555
# Epoch: 600 Error: 102.20405360685024 Sensitivity: 0.53 specificity: 0.55
# Epoch: 700 Error: 102.1703636754079 Sensitivity: 0.5475 specificity: 0.55
# Epoch: 800 Error: 102.05437976628399 Sensitivity: 0.5525 specificity: 0.5525
# Epoch: 900 Error: 102.00104900652151 Sensitivity: 0.555 specificity: 0.5525
# Epoch: 1000 Error: 101.98715931183678 Sensitivity: 0.555 specificity: 0.5625
# Epoch: 1100 Error: 101.98724560455072 Sensitivity: 0.555 specificity: 0.5675
# Epoch: 1200 Error: 101.88824679866086 Sensitivity: 0.555 specificity: 0.565
# Epoch: 1300 Error: 101.79972844549175 Sensitivity: 0.57 specificity: 0.5625
# Epoch: 1400 Error: 101.64532910247318 Sensitivity: 0.57 specificity: 0.565
# Epoch: 1500 Error: 101.40199549927578 Sensitivity: 0.57 specificity: 0.5675
# Epoch: 1600 Error: 101.12802764917531 Sensitivity: 0.57 specificity: 0.5625
# Epoch: 1700 Error: 100.83331655739757 Sensitivity: 0.535 specificity: 0.5725
# Epoch: 1800 Error: 100.52634312780215 Sensitivity: 0.535 specificity: 0.585
# Epoch: 1900 Error: 100.21773344849798 Sensitivity: 0.5175 specificity: 0.585
# Epoch: 2000 Error: 99.91109972130607 Sensitivity: 0.5175 specificity: 0.595
# Epoch: 2100 Error: 99.60271930385264 Sensitivity: 0.5325 specificity: 0.5925
# Epoch: 2200 Error: 99.32701939690226 Sensitivity: 0.545 specificity: 0.6025
# Epoch: 2300 Error: 99.11603541871204 Sensitivity: 0.545 specificity: 0.6075
# Epoch: 2400 Error: 98.97243271665253 Sensitivity: 0.545 specificity: 0.615
# Epoch: 2500 Error: 98.7551648890818 Sensitivity: 0.545 specificity: 0.6175
# Epoch: 2600 Error: 98.50198178792456 Sensitivity: 0.5275 specificity: 0.625
# Epoch: 2700 Error: 98.24908802415358 Sensitivity: 0.5275 specificity: 0.63
# Epoch: 2800 Error: 98.00614261423468 Sensitivity: 0.555 specificity: 0.635
# Epoch: 2900 Error: 97.77802937478171 Sensitivity: 0.555 specificity: 0.6375
# Epoch: 3000 Error: 97.55059697605614 Sensitivity: 0.53 specificity: 0.6375
# Epoch: 3100 Error: 97.32938554095982 Sensitivity: 0.5125 specificity: 0.6375
# Epoch: 3200 Error: 97.11718886044288 Sensitivity: 0.5125 specificity: 0.63
# Epoch: 3300 Error: 96.91437535632193 Sensitivity: 0.5125 specificity: 0.63
# Epoch: 3400 Error: 96.7274108055889 Sensitivity: 0.5125 specificity: 0.6325
# Epoch: 3500 Error: 96.5464372881911 Sensitivity: 0.5125 specificity: 0.6325
# Epoch: 3600 Error: 96.37783708391623 Sensitivity: 0.5125 specificity: 0.6275
# Epoch: 3700 Error: 96.21962954993133 Sensitivity: 0.5125 specificity: 0.6325
# Epoch: 3800 Error: 96.08814976828133 Sensitivity: 0.5125 specificity: 0.635
# Epoch: 3900 Error: 95.97305771146793 Sensitivity: 0.4975 specificity: 0.6375

# %%
preds = model_1.predict(test_i,bias=False)
acc = float(list(np.logical_xor(test_t,preds)).count(False))/len(test_t)
print("Model 1 acc:",acc)
# print(Etss_1b, specif_1b, sens_1b )
# Out:
# Model 1 acc: 0.6979166666666666

# %%
#case 1: determine learning rate

model_1.weights=load_weights("model_1")
Etss_1c, specif_1c, sens_1c = model_1.train(norm_train_i,train_t,adaptive_rate = True,alpha0= 0.003,
                                   bias=False,momentum_enabled=False ,max_iteration = 5000)
# Out:
# Epoch: 0 Error: 127.76428086786098 Sensitivity: 0.0 specificity: 0.9975
# Epoch: 100 Error: 126.85070173939745 Sensitivity: 0.0 specificity: 0.9975
# Epoch: 200 Error: 126.17622590627026 Sensitivity: 0.0 specificity: 0.9975
# Epoch: 300 Error: 125.7419202427807 Sensitivity: 0.0 specificity: 0.9975
# Epoch: 400 Error: 125.43875396151442 Sensitivity: 0.0 specificity: 0.9975
# Epoch: 500 Error: 125.20443798921181 Sensitivity: 0.0 specificity: 0.9975
# Epoch: 600 Error: 125.00141536046898 Sensitivity: 0.0 specificity: 0.9975
# Epoch: 700 Error: 124.82622462187558 Sensitivity: 0.0 specificity: 0.9975
# Epoch: 800 Error: 124.6699074987922 Sensitivity: 0.0 specificity: 0.9975
# Epoch: 900 Error: 124.52862627395963 Sensitivity: 0.0 specificity: 0.9975
# Epoch: 1000 Error: 124.39827137315652 Sensitivity: 0.0 specificity: 0.9975
# Epoch: 1100 Error: 124.27387079503727 Sensitivity: 0.0 specificity: 0.9975
# Epoch: 1200 Error: 124.15756619919081 Sensitivity: 0.0 specificity: 0.9975
# Epoch: 1300 Error: 124.04828986464881 Sensitivity: 0.0 specificity: 0.9975
# Epoch: 1400 Error: 123.95248152025454 Sensitivity: 0.0 specificity: 0.9975
# Epoch: 1500 Error: 123.86900104101288 Sensitivity: 0.0 specificity: 0.9975
# Epoch: 1600 Error: 123.79028867822745 Sensitivity: 0.0 specificity: 0.9975
# Epoch: 1700 Error: 123.71622737715431 Sensitivity: 0.0 specificity: 0.9975
# Epoch: 1800 Error: 123.64488082846879 Sensitivity: 0.0 specificity: 0.9975
# Epoch: 1900 Error: 123.57612902633662 Sensitivity: 0.0 specificity: 0.9975
# Epoch: 2000 Error: 123.50975187470223 Sensitivity: 0.0 specificity: 0.9975
# Epoch: 2100 Error: 123.44585462274486 Sensitivity: 0.0 specificity: 0.9975
# Epoch: 2200 Error: 123.3847009170521 Sensitivity: 0.0 specificity: 0.9975
# Epoch: 2300 Error: 123.32541700418768 Sensitivity: 0.0 specificity: 0.9975
# Epoch: 2400 Error: 123.2673038487132 Sensitivity: 0.0 specificity: 0.9975
# Epoch: 2500 Error: 123.2107489156197 Sensitivity: 0.0 specificity: 0.9975
# Epoch: 2600 Error: 123.15560560709098 Sensitivity: 0.0 specificity: 0.9975
# Epoch: 2700 Error: 123.10122079478447 Sensitivity: 0.0 specificity: 0.9975
# Epoch: 2800 Error: 123.04820687349626 Sensitivity: 0.0 specificity: 0.9975
# Epoch: 2900 Error: 122.99744064011728 Sensitivity: 0.0 specificity: 0.9975
# Epoch: 3000 Error: 122.94820076279026 Sensitivity: 0.0 specificity: 0.9975
# Epoch: 3100 Error: 122.90021448751223 Sensitivity: 0.0 specificity: 0.9975
# Epoch: 3200 Error: 122.85343674587642 Sensitivity: 0.0 specificity: 0.9975
# Epoch: 3300 Error: 122.80785652425348 Sensitivity: 0.0 specificity: 0.9975
# Epoch: 3400 Error: 122.7621070807509 Sensitivity: 0.0 specificity: 0.9975
# Epoch: 3500 Error: 122.71674317697533 Sensitivity: 0.0 specificity: 0.9975
# Epoch: 3600 Error: 122.6744599789224 Sensitivity: 0.0 specificity: 0.9975
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-76-bec9615edcf8> in <module>()
#       3 model_1.weights=load_weights("model_1")
#       4 Etss_1c, specif_1c, sens_1c = model_1.train(norm_train_i,train_t,adaptive_rate = True,alpha0= 0.003,
# ----> 5                                    bias=False,momentum_enabled=False ,max_iteration = 5000)
#
# <ipython-input-59-9da7355644ce> in train(self, inputs, targets, adaptive_rate, alpha0, beta0, bias, momentum_enabled, max_iteration, interval)
#     177
#     178                 err  += 0.5*pow(targets[i]-pred[0], 2)
# --> 179                 self.backforward(outs,targets[i],bias)
#     180             #trained by epoch
#     181             m = self.gradient_descent(alpha, beta,momentum)
#
# <ipython-input-59-9da7355644ce> in backforward(self, out, target, bias)
#      90         """
#      91         pred = out[self.num_layer]
# ---> 92         dE_o = -(target- pred)
#      93         prev_net = np.dot(out[self.num_layer-1], self.weights[self.num_layer-1][1:,:])
#      94         if bias:
#
# KeyboardInterrupt:

# %%
preds = model_1.predict(test_i,bias=False)
acc = float(list(np.logical_xor(test_t,preds)).count(False))/len(test_t)
print("Model 1 acc:",acc)
# print(Etss_1b, specif_1b, sens_1b )
# Out:
# Model 1 acc: 0.5638020833333334

# %%
#case 3 uses the weights from case 1
model_3 = MLFF(input_shape  = d)
model_3.add_layer((d,2*d+1),activation='relu')
model_3.add_layer((2*d+1,1),initializer='')

# %%
model_3.weights=load_weights("model_1")
Etss_3a, specif_3a, sens_3a = model_3.train(norm_train_i,train_t,adaptive_rate = True,alpha0= 0.5,
                                   bias=False,momentum_enabled=True ,max_iteration = 5000)
# Out:
# Epoch: 0 Error: 14.78629757727794 Sensitivity: 0.0 specificity: 0.9830508474576272
# Epoch: 100 Error: 14.560335450215879 Sensitivity: 0.6610169491525424 specificity: 0.576271186440678
# Epoch: 200 Error: 14.503434494963964 Sensitivity: 0.6271186440677966 specificity: 0.6271186440677966
# Epoch: 300 Error: 14.499530523112933 Sensitivity: 0.5932203389830508 specificity: 0.6101694915254238
# Epoch: 400 Error: 14.518910433520208 Sensitivity: 0.6271186440677966 specificity: 0.5254237288135594
# Epoch: 500 Error: 14.554455949284534 Sensitivity: 0.5932203389830508 specificity: 0.4915254237288136
# Epoch: 600 Error: 14.603521634207711 Sensitivity: 0.559322033898305 specificity: 0.5254237288135594
# Epoch: 700 Error: 14.667283100704038 Sensitivity: 0.5423728813559322 specificity: 0.5254237288135594
# Epoch: 800 Error: 14.738043890648399 Sensitivity: 0.5423728813559322 specificity: 0.4915254237288136
# Epoch: 900 Error: 14.814403516557611 Sensitivity: 0.5423728813559322 specificity: 0.4406779661016949

# %%
epochs = [i*100 for i in range(len(Etss_3a))]
save_curves(3,"momentum",epochs,Etss_3a, specif_3a, sens_3a )

# %%
preds = model_3.predict(test_i,bias=False)
acc = float(list(np.logical_xor(test_t,preds)).count(False))/len(test_t)
print("Model 3 acc:",acc)
# print(Etss_1b, specif_1b, sens_1b )
# Out:
# Model 1 acc: 0.6731770833333334
